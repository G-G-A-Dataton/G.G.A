# %% [markdown]
# # LightGBM Baseline Notebook (Archived)
#
# This notebook preserves the 4 July baseline milestone. Its former executable cells used partial positive-row sampling and threshold selection on the same OOF predictions used for reporting, so those results are not valid under the final competition contract.

# %% [markdown]
# ## Canonical replacement
#
# Run the grouped lexical baseline from the repository root:
#
# ```bash
# python scripts/training/run_baseline.py --sample-terms 100
# ```
#
# The replacement samples complete `term_id` groups, excludes every known positive from negative candidates, uses `StratifiedGroupKFold`, and reports cross-fitted threshold performance. The final production workflow is documented in `RUNBOOK.md`.
